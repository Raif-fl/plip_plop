# %% [markdown]
# # Setup

# %% [markdown]
# ## Load packages

# %%
import torch

print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# CUDA available: False

# %%
import os
import glob

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

torch.set_num_threads(4)

print("PyTorch threads:", torch.get_num_threads())
# Out:
# PyTorch threads: 4

# %% [markdown]
# ## Load results

# %%
INPUT_DIR = "/tscc/lustre/ddn/scratch/kflanagan/RNA_protein_grammar/ml_inputs"

COMPARISON_TABLE = (
    "/tscc/nfs/home/kflanagan/projects/RNA_protein_grammar/"
    "machine_learning_prototype/encode_initial_30_comparisons.tsv"
)

comparison_table = pd.read_csv(COMPARISON_TABLE, sep="\t")

comparison_table[["category", "experiment_A", "experiment_B"]].head()
# Out:
#   category             experiment_A             experiment_B
# 0  similar    FUS_HepG2_ENCSR464OSH  TAF15_HepG2_ENCSR841EQA
# 1  similar    PUM1_K562_ENCSR308YNT    PUM2_K562_ENCSR661ICQ
# 2  similar  PCBP1_HepG2_ENCSR256CHX  PCBP2_HepG2_ENCSR339FUY
# 3  similar   TIA1_HepG2_ENCSR623VEQ  TIAL1_HepG2_ENCSR322HHA
# 4  similar    SAFB_K562_ENCSR484LAB   SAFB2_K562_ENCSR943MHU

# %% [markdown]
# # Running pytorch

# %% [markdown]
# ## Data setup

# %% [markdown]
# ### Create metadata

# %%
all_signals = []
all_metadata = []

for comparison_id, row in comparison_table.iterrows():
    experiment_A = row["experiment_A"]
    experiment_B = row["experiment_B"]

    npz_file = os.path.join(
        INPUT_DIR,
        f"{experiment_A}_{experiment_B}.npz"
    )

    if not os.path.exists(npz_file):
        print(f"Missing: {npz_file}")
        continue

    data = np.load(npz_file)

    # Log-transform the RPM signal exactly as in the one-RBP prototype.
    signals = np.log1p(data["signals"]).astype(np.float32)

    n_windows = len(signals)

    all_signals.append(signals)

    metadata = pd.DataFrame({
        "comparison_id": comparison_id,
        "category": row["category"],
        "experiment_A": experiment_A,
        "experiment_B": experiment_B,
        "chrom": data["chrom"],
        "start": data["start"],
        "end": data["end"],
        "strand": data["strand"],
        "region_id": data["region_id"],
        "block_number": data["block_number"]
    })

    all_metadata.append(metadata)

# %%
signals = np.concatenate(all_signals, axis=0)
metadata = pd.concat(all_metadata, ignore_index=True)

print("Signal shape:", signals.shape)
print("Metadata shape:", metadata.shape)
print("Number of comparisons:", metadata["comparison_id"].nunique())
# Out:
# Signal shape: (717750, 2, 300)
# Metadata shape: (717750, 10)
# Number of comparisons: 30

# %% [markdown]
# #### Check comparisons

# %%
comparison_counts = (
    metadata
    .groupby(["comparison_id", "category", "experiment_A", "experiment_B"])
    .size()
    .reset_index(name="n_windows")
    .sort_values("n_windows", ascending=False)
)

comparison_counts
# Out:
#     comparison_id   category              experiment_A  \
# 28             28  unrelated    SND1_HepG2_ENCSR061EVO
# 24             24  unrelated    KHSRP_K562_ENCSR438GZQ
# 5               5    similar   CSTF2_HepG2_ENCSR384MWO
# 19             19    complex   PRPF4_HepG2_ENCSR977OXG
# 25             25  unrelated    YBX3_HepG2_ENCSR735HOK
# 4               4    similar     SAFB_K562_ENCSR484LAB
# 18             18    complex    CPSF6_K562_ENCSR532VUB
# 26             26  unrelated    ILF3_HepG2_ENCSR786TSC
# 12             12    complex   PRPF8_HepG2_ENCSR121NVA
# 23             23  unrelated  HNRNPC_HepG2_ENCSR550DVK
# 0               0    similar     FUS_HepG2_ENCSR464OSH
# 21             21  unrelated  RBFOX2_HepG2_ENCSR987FTF
# 29             29  unrelated      QKI_K562_ENCSR366YOG
# 11             11    complex   U2AF1_HepG2_ENCSR328LLU
# 6               6    similar  IGF2BP1_K562_ENCSR975KIR
# 2               2    similar   PCBP1_HepG2_ENCSR256CHX
# 3               3    similar    TIA1_HepG2_ENCSR623VEQ
# 14             14    complex   EIF3D_HepG2_ENCSR041NUV
# 22             22  unrelated    UPF1_HepG2_ENCSR539BEV
# 20             20  unrelated   LIN28B_K562_ENCSR970NKP
# 1               1    similar     PUM1_K562_ENCSR308YNT
# 7               7    similar     FMR1_K562_ENCSR331VNX
# 13             13    complex   SF3A3_HepG2_ENCSR331MIC
# 9               9    similar    DDX21_K562_ENCSR040QLV
# 8               8    similar    SRSF1_K562_ENCSR432XUP
# 10             10    complex  DROSHA_HepG2_ENCSR834YLD
# 17             17    complex    LSM11_K562_ENCSR022BVV
# 16             16    complex    DKC1_HepG2_ENCSR301TFY
# 15             15    complex     RPS3_K562_ENCSR120EAR
# 27             27  unrelated      FTO_K562_ENCSR989SMC
#
#                 experiment_B  n_windows
# 28   GRWD1_HepG2_ENCSR893NWB     114365
# 24    NOLC1_K562_ENCSR001VAC      75892
# 5   CSTF2T_HepG2_ENCSR919HSE      54507
# 19   PRPF8_HepG2_ENCSR121NVA      53310
# 25   DDX55_HepG2_ENCSR845VGB      47110
# 4     SAFB2_K562_ENCSR943MHU      41498
# 18   CSTF2T_K562_ENCSR840DRD      33479
# 26   NCBP2_HepG2_ENCSR018RVZ      29323
# 12  EFTUD2_HepG2_ENCSR527DXF      20344
# 23   AKAP1_HepG2_ENCSR356ZMO      19439
# 0    TAF15_HepG2_ENCSR841EQA      17981
# 21   DDX3X_HepG2_ENCSR648LAH      17064
# 29    NOLC1_K562_ENCSR001VAC      16846
# 11   U2AF2_HepG2_ENCSR202BFN      16699
# 6   IGF2BP2_K562_ENCSR062NNB      16500
# 2    PCBP2_HepG2_ENCSR339FUY      15325
# 3    TIAL1_HepG2_ENCSR322HHA      14197
# 14   EIF3H_HepG2_ENCSR916XIV      13557
# 22   LARP7_HepG2_ENCSR961OKA      13512
# 20    XRCC6_K562_ENCSR258QKO      13393
# 1      PUM2_K562_ENCSR661ICQ      12955
# 7      FXR1_K562_ENCSR774RFN      12319
# 13   SF3B4_HepG2_ENCSR279UJF      11890
# 9     DDX24_K562_ENCSR999WKT      11030
# 8     SRSF7_K562_ENCSR468FSW      10548
# 10   DGCR8_HepG2_ENCSR061SZV       7995
# 17     SLBP_K562_ENCSR483NOP       2554
# 16   DDX55_HepG2_ENCSR845VGB       1719
# 15    RPS11_K562_ENCSR269AJF       1331
# 27     XRN2_K562_ENCSR657TZB       1068

# %%
print("Smallest comparison:", comparison_counts["n_windows"].min())
print("Largest comparison:", comparison_counts["n_windows"].max())
print("Ratio:", comparison_counts["n_windows"].max() / comparison_counts["n_windows"].min())
# Out:
# Smallest comparison: 1068
# Largest comparison: 114365
# Ratio: 107.08333333333333

# %% [markdown]
# ### Weighting

# %%
# Set weighting alpha to 0.5 (square root). 
alpha = 0.5

# Create the weights. 
comparison_counts["window_weight"] = (
    comparison_counts["n_windows"] ** (alpha - 1)
)

# create a dictionary for quickly grabbing each weight for each comparison. 
weight_map = dict(zip(
    comparison_counts["comparison_id"],
    comparison_counts["window_weight"]
))

# Add weights to metadata. 
metadata["weight"] = metadata["comparison_id"].map(weight_map)

# %% [markdown]
# #### Check weights

# %%
effective_weights = (
    metadata
    .groupby("comparison_id")["weight"]
    .sum()
    .reset_index(name="total_weight")
)

effective_weights = effective_weights.merge(
    comparison_counts[
        ["comparison_id", "experiment_A", "experiment_B", "n_windows"]
    ],
    on="comparison_id"
)

effective_weights
# Out:
#     comparison_id  total_weight              experiment_A  \
# 0               0    134.093251     FUS_HepG2_ENCSR464OSH
# 1               1    113.820033     PUM1_K562_ENCSR308YNT
# 2               2    123.794184   PCBP1_HepG2_ENCSR256CHX
# 3               3    119.151164    TIA1_HepG2_ENCSR623VEQ
# 4               4    203.710579     SAFB_K562_ENCSR484LAB
# 5               5    233.467342   CSTF2_HepG2_ENCSR384MWO
# 6               6    128.452326  IGF2BP1_K562_ENCSR975KIR
# 7               7    110.990991     FMR1_K562_ENCSR331VNX
# 8               8    102.703457    SRSF1_K562_ENCSR432XUP
# 9               9    105.023807    DDX21_K562_ENCSR040QLV
# 10             10     89.414764  DROSHA_HepG2_ENCSR834YLD
# 11             11    129.224611   U2AF1_HepG2_ENCSR328LLU
# 12             12    142.632395   PRPF8_HepG2_ENCSR121NVA
# 13             13    109.041277   SF3A3_HepG2_ENCSR331MIC
# 14             14    116.434531   EIF3D_HepG2_ENCSR041NUV
# 15             15     36.482873     RPS3_K562_ENCSR120EAR
# 16             16     41.460825    DKC1_HepG2_ENCSR301TFY
# 17             17     50.537115    LSM11_K562_ENCSR022BVV
# 18             18    182.972676    CPSF6_K562_ENCSR532VUB
# 19             19    230.889584   PRPF4_HepG2_ENCSR977OXG
# 20             20    115.728130   LIN28B_K562_ENCSR970NKP
# 21             21    130.629246  RBFOX2_HepG2_ENCSR987FTF
# 22             22    116.241129    UPF1_HepG2_ENCSR539BEV
# 23             23    139.423814  HNRNPC_HepG2_ENCSR550DVK
# 24             24    275.485027    KHSRP_K562_ENCSR438GZQ
# 25             25    217.048382    YBX3_HepG2_ENCSR735HOK
# 26             26    171.239598    ILF3_HepG2_ENCSR786TSC
# 27             27     32.680269      FTO_K562_ENCSR989SMC
# 28             28    338.178947    SND1_HepG2_ENCSR061EVO
# 29             29    129.792142      QKI_K562_ENCSR366YOG
#
#                 experiment_B  n_windows
# 0    TAF15_HepG2_ENCSR841EQA      17981
# 1      PUM2_K562_ENCSR661ICQ      12955
# 2    PCBP2_HepG2_ENCSR339FUY      15325
# 3    TIAL1_HepG2_ENCSR322HHA      14197
# 4     SAFB2_K562_ENCSR943MHU      41498
# 5   CSTF2T_HepG2_ENCSR919HSE      54507
# 6   IGF2BP2_K562_ENCSR062NNB      16500
# 7      FXR1_K562_ENCSR774RFN      12319
# 8     SRSF7_K562_ENCSR468FSW      10548
# 9     DDX24_K562_ENCSR999WKT      11030
# 10   DGCR8_HepG2_ENCSR061SZV       7995
# 11   U2AF2_HepG2_ENCSR202BFN      16699
# 12  EFTUD2_HepG2_ENCSR527DXF      20344
# 13   SF3B4_HepG2_ENCSR279UJF      11890
# 14   EIF3H_HepG2_ENCSR916XIV      13557
# 15    RPS11_K562_ENCSR269AJF       1331
# 16   DDX55_HepG2_ENCSR845VGB       1719
# 17     SLBP_K562_ENCSR483NOP       2554
# 18   CSTF2T_K562_ENCSR840DRD      33479
# 19   PRPF8_HepG2_ENCSR121NVA      53310
# 20    XRCC6_K562_ENCSR258QKO      13393
# 21   DDX3X_HepG2_ENCSR648LAH      17064
# 22   LARP7_HepG2_ENCSR961OKA      13512
# 23   AKAP1_HepG2_ENCSR356ZMO      19439
# 24    NOLC1_K562_ENCSR001VAC      75892
# 25   DDX55_HepG2_ENCSR845VGB      47110
# 26   NCBP2_HepG2_ENCSR018RVZ      29323
# 27     XRN2_K562_ENCSR657TZB       1068
# 28   GRWD1_HepG2_ENCSR893NWB     114365
# 29    NOLC1_K562_ENCSR001VAC      16846

# %%
region_counts = (
    metadata
    .groupby("comparison_id")["region_id"]
    .nunique()
    .reset_index(name="n_regions")
)

comparison_counts = comparison_counts.merge(region_counts, on="comparison_id")

comparison_counts[
    ["category", "experiment_A", "experiment_B", "n_windows", "n_regions"]
].sort_values("n_windows")
# Out:
#      category              experiment_A              experiment_B  n_windows  \
# 29  unrelated      FTO_K562_ENCSR989SMC     XRN2_K562_ENCSR657TZB       1068
# 28    complex     RPS3_K562_ENCSR120EAR    RPS11_K562_ENCSR269AJF       1331
# 27    complex    DKC1_HepG2_ENCSR301TFY   DDX55_HepG2_ENCSR845VGB       1719
# 26    complex    LSM11_K562_ENCSR022BVV     SLBP_K562_ENCSR483NOP       2554
# 25    complex  DROSHA_HepG2_ENCSR834YLD   DGCR8_HepG2_ENCSR061SZV       7995
# 24    similar    SRSF1_K562_ENCSR432XUP    SRSF7_K562_ENCSR468FSW      10548
# 23    similar    DDX21_K562_ENCSR040QLV    DDX24_K562_ENCSR999WKT      11030
# 22    complex   SF3A3_HepG2_ENCSR331MIC   SF3B4_HepG2_ENCSR279UJF      11890
# 21    similar     FMR1_K562_ENCSR331VNX     FXR1_K562_ENCSR774RFN      12319
# 20    similar     PUM1_K562_ENCSR308YNT     PUM2_K562_ENCSR661ICQ      12955
# 19  unrelated   LIN28B_K562_ENCSR970NKP    XRCC6_K562_ENCSR258QKO      13393
# 18  unrelated    UPF1_HepG2_ENCSR539BEV   LARP7_HepG2_ENCSR961OKA      13512
# 17    complex   EIF3D_HepG2_ENCSR041NUV   EIF3H_HepG2_ENCSR916XIV      13557
# 16    similar    TIA1_HepG2_ENCSR623VEQ   TIAL1_HepG2_ENCSR322HHA      14197
# 15    similar   PCBP1_HepG2_ENCSR256CHX   PCBP2_HepG2_ENCSR339FUY      15325
# 14    similar  IGF2BP1_K562_ENCSR975KIR  IGF2BP2_K562_ENCSR062NNB      16500
# 13    complex   U2AF1_HepG2_ENCSR328LLU   U2AF2_HepG2_ENCSR202BFN      16699
# 12  unrelated      QKI_K562_ENCSR366YOG    NOLC1_K562_ENCSR001VAC      16846
# 11  unrelated  RBFOX2_HepG2_ENCSR987FTF   DDX3X_HepG2_ENCSR648LAH      17064
# 10    similar     FUS_HepG2_ENCSR464OSH   TAF15_HepG2_ENCSR841EQA      17981
# 9   unrelated  HNRNPC_HepG2_ENCSR550DVK   AKAP1_HepG2_ENCSR356ZMO      19439
# 8     complex   PRPF8_HepG2_ENCSR121NVA  EFTUD2_HepG2_ENCSR527DXF      20344
# 7   unrelated    ILF3_HepG2_ENCSR786TSC   NCBP2_HepG2_ENCSR018RVZ      29323
# 6     complex    CPSF6_K562_ENCSR532VUB   CSTF2T_K562_ENCSR840DRD      33479
# 5     similar     SAFB_K562_ENCSR484LAB    SAFB2_K562_ENCSR943MHU      41498
# 4   unrelated    YBX3_HepG2_ENCSR735HOK   DDX55_HepG2_ENCSR845VGB      47110
# 3     complex   PRPF4_HepG2_ENCSR977OXG   PRPF8_HepG2_ENCSR121NVA      53310
# 2     similar   CSTF2_HepG2_ENCSR384MWO  CSTF2T_HepG2_ENCSR919HSE      54507
# 1   unrelated    KHSRP_K562_ENCSR438GZQ    NOLC1_K562_ENCSR001VAC      75892
# 0   unrelated    SND1_HepG2_ENCSR061EVO   GRWD1_HepG2_ENCSR893NWB     114365
#
#     n_regions
# 29        818
# 28        997
# 27       1174
# 26       1656
# 25       4121
# 24       8068
# 23       8432
# 22       9321
# 21       8483
# 20       9297
# 19      10762
# 18       5722
# 17       9190
# 16      10262
# 15      10566
# 14      10013
# 13      12448
# 12      10572
# 11      10452
# 10      11802
# 9       12816
# 8       15087
# 7       20937
# 6       16158
# 5       22329
# 4       26832
# 3       32211
# 2       27047
# 1       48897
# 0       66349

# %% [markdown]
# ## Train/val split setup.

# %%
# Create a combined identifier from comparison and region. 
metadata["region_key"] = (
    metadata["comparison_id"].astype(str)
    + "_"
    + metadata["region_id"].astype(str)
)

# %%
# Setup random seed. 
rng = np.random.default_rng(42)

# Initialize masking vector. 
train_mask = np.zeros(len(metadata), dtype=bool)
val_mask = np.zeros(len(metadata), dtype=bool)

# Build mask. 
for comparison_id in metadata["comparison_id"].unique():
    comparison_rows = metadata["comparison_id"] == comparison_id

    comparison_regions = (
        metadata.loc[comparison_rows, "region_key"]
        .unique()
        .copy()
    )

    rng.shuffle(comparison_regions)

    split = int(len(comparison_regions) * 0.8)

    train_regions = comparison_regions[:split]
    val_regions = comparison_regions[split:]

    train_mask |= metadata["region_key"].isin(train_regions)
    val_mask |= metadata["region_key"].isin(val_regions)

# %%
# Apply mask to the signals.  
train_signals = signals[train_mask]
val_signals = signals[val_mask]

# apply mask to the metadata. 
train_metadata = metadata.loc[train_mask].reset_index(drop=True)
val_metadata = metadata.loc[val_mask].reset_index(drop=True)

print("Training windows:", len(train_signals))
print("Validation windows:", len(val_signals))
# Out:
# Training windows: 574631
# Validation windows: 143119

# %% [markdown]
# ### Check train/val split

# %%
# Ensure no overlapping regions between the training and test dataset. 
overlap = set(train_metadata["region_key"]) & set(val_metadata["region_key"])

print("Overlapping regions:", len(overlap))
# Out:
# Overlapping regions: 0

# %%
# Check to ensure there are some training and validation windows for each comparison. 
split_counts = pd.DataFrame({
    "train": train_metadata.groupby("comparison_id").size(),
    "validation": val_metadata.groupby("comparison_id").size()
}).fillna(0).astype(int)

split_counts
# Out:
#                train  validation
# comparison_id
# 0              14364        3617
# 1              10359        2596
# 2              12250        3075
# 3              11403        2794
# 4              33267        8231
# 5              43706       10801
# 6              13174        3326
# 7               9821        2498
# 8               8452        2096
# 9               8809        2221
# 10              6481        1514
# 11             13335        3364
# 12             16344        4000
# 13              9515        2375
# 14             10909        2648
# 15              1054         277
# 16              1371         348
# 17              2025         529
# 18             26852        6627
# 19             42581       10729
# 20             10719        2674
# 21             13697        3367
# 22             10825        2687
# 23             15474        3965
# 24             60678       15214
# 25             37704        9406
# 26             23540        5783
# 27               850         218
# 28             91718       22647
# 29             13354        3492

# %%
# Check balance between categories for training and validation data. 
print("Training:")
print(train_metadata["category"].value_counts())
print("\nValidation:")
print(val_metadata["category"].value_counts())
# Out:
# Training:
# category
# unrelated    278559
# similar      165605
# complex      130467
# Name: count, dtype: int64
#
# Validation:
# category
# unrelated    69453
# similar      41255
# complex      32411
# Name: count, dtype: int64

# %% [markdown]
# ## Setup data loaders.

# %%
# Create special data class for machine learning. 
class RBPWindowDataset(Dataset):
    def __init__(self, signals, weights):
        self.signals = torch.tensor(signals, dtype=torch.float32)
        self.weights = torch.tensor(weights, dtype=torch.float32)

    def __len__(self):
        return(len(self.signals))

    def __getitem__(self, idx):
        return(self.signals[idx], self.weights[idx])

train_weights = train_metadata["weight"].to_numpy(dtype=np.float32)
val_weights = val_metadata["weight"].to_numpy(dtype=np.float32)

train_dataset = RBPWindowDataset(train_signals, train_weights)
val_dataset = RBPWindowDataset(val_signals, val_weights)

train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=128, shuffle=False)

# %%
batch_signals, batch_weights = next(iter(train_loader))

print("Signals:", batch_signals.shape)
print("Weights:", batch_weights.shape)
print("First few weights:", batch_weights[:10])
# Out:
# Signals: torch.Size([128, 2, 300])
# Weights: torch.Size([128])
# First few weights: tensor([0.0036, 0.0084, 0.0049, 0.0043, 0.0043, 0.0075, 0.0058, 0.0030, 0.0084,
#         0.0030])

# %%
print("Train weight range:", train_weights.min(), train_weights.max())
print("Validation weight range:", val_weights.min(), val_weights.max())
# Out:
# Train weight range: 0.0029570144 0.030599503
# Validation weight range: 0.0029570144 0.030599503

# %% [markdown]
# ## Model setup

# %%
def weighted_mse_loss(reconstruction, target, weights):
    # Calculate mean squared error separately for each window.
    per_window_loss = (reconstruction - target) ** 2
    per_window_loss = per_window_loss.mean(dim=(1, 2))

    # Weight each window according to its comparison size.
    weighted_loss = (per_window_loss * weights).sum() / weights.sum()

    return(weighted_loss)

# %%
# Set threads equal to number of available CPUs. 
torch.set_num_threads(4)
print("PyTorch threads:", torch.get_num_threads())

class SimpleAutoencoder(nn.Module):
    def __init__(self, latent_dim=64):
        super().__init__()

        # Encoder.
        self.conv1 = nn.Conv1d(in_channels=2, out_channels=16, kernel_size=7, padding=3)
        self.pool1 = nn.MaxPool1d(2)

        self.conv2 = nn.Conv1d(in_channels=16, out_channels=32, kernel_size=5, padding=2)
        self.pool2 = nn.MaxPool1d(2)

        self.flatten = nn.Flatten()
        self.encoder_fc = nn.Linear(32 * 75, latent_dim)

        # Decoder.
        self.decoder_fc = nn.Linear(latent_dim, 32 * 75)

        self.deconv1 = nn.ConvTranspose1d(
            in_channels=32,
            out_channels=16,
            kernel_size=4,
            stride=2,
            padding=1
        )

        self.deconv2 = nn.ConvTranspose1d(
            in_channels=16,
            out_channels=2,
            kernel_size=4,
            stride=2,
            padding=1
        )

        self.relu = nn.ReLU()

    def encode(self, x):
        x = self.relu(self.conv1(x))
        x = self.pool1(x)

        x = self.relu(self.conv2(x))
        x = self.pool2(x)

        x = self.flatten(x)
        x = self.encoder_fc(x)

        return(x)

    def decode(self, x):
        x = self.relu(self.decoder_fc(x))

        # Turn the 2400 values back into 32 feature maps × 75 positions.
        x = x.view(-1, 32, 75)

        x = self.relu(self.deconv1(x))
        x = self.deconv2(x)

        return(x)

    def forward(self, x):
        latent = self.encode(x)
        reconstruction = self.decode(latent)

        return(reconstruction)
# Out:
# PyTorch threads: 4

# %%
# Set model as autoencode
model = SimpleAutoencoder(latent_dim=64)

# Select mean square error. 
criterion = nn.MSELoss()

# Adam optimizer (what is adam?)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# ## Run model

# %%
train_losses = []
val_losses = []

best_val_loss = float("inf")
best_model_state = None

num_epochs = 20

for epoch in range(num_epochs):
    model.train()
    total_train_loss = 0

    for batch_signals, batch_weights in train_loader:
        optimizer.zero_grad()
    
        reconstruction = model(batch_signals)
        loss = weighted_mse_loss(
            reconstruction,
            batch_signals,
            batch_weights
        )
    
        loss.backward()
        optimizer.step()
    
        total_train_loss += loss.item()

    average_train_loss = total_train_loss / len(train_loader)

    model.eval()
    total_val_loss = 0

    with torch.no_grad():
        for batch_signals, batch_weights in val_loader:
            reconstruction = model(batch_signals)
    
            loss = weighted_mse_loss(
                reconstruction,
                batch_signals,
                batch_weights
            )
    
            total_val_loss += loss.item()

    average_val_loss = total_val_loss / len(val_loader)

    train_losses.append(average_train_loss)
    val_losses.append(average_val_loss)

    if average_val_loss < best_val_loss:
        best_val_loss = average_val_loss
        best_model_state = {
            key: value.cpu().clone()
            for key, value in model.state_dict().items()
        }

    print(
        f"Epoch {epoch + 1}: "
        f"train = {average_train_loss:.6f}, "
        f"validation = {average_val_loss:.6f}"
    )
# Out:
# Epoch 1: train = 0.009960, validation = 0.011517

# %%
# Loads best model, not just last model. 
model.load_state_dict(best_model_state)

print(f"Best validation loss: {best_val_loss:.6f}")

# %% [markdown]
# ## Diagnostics

# %%
plt.figure(figsize=(8, 4))
plt.plot(train_losses, label="Training")
plt.plot(val_losses, label="Validation")
plt.xlabel("Epoch")
plt.ylabel("MSE loss")
plt.legend()
plt.show()

# %%
batch = next(iter(train_loader))
reconstruction = model(batch)

i = 0

original = batch[i].detach().numpy()
reconstructed = reconstruction[i].detach().numpy()

plt.figure(figsize=(10, 4))

plt.plot(original[0], label="RBP A original")
plt.plot(reconstructed[0], label="RBP A reconstruction", linestyle="--")

plt.plot(original[1], label="RBP B original")
plt.plot(reconstructed[1], label="RBP B reconstruction", linestyle="--")

plt.xlabel("Position")
plt.ylabel("RPM signal")
plt.legend()
plt.show()

# %% [markdown]
# ## Clustering/PCA

# %%
model.eval()

latent_vectors = []
validation_signals = []

with torch.no_grad():
    for batch in val_loader:
        latent = model.encode(batch)

        latent_vectors.append(latent.numpy())
        validation_signals.append(batch.numpy())

latent_vectors = np.concatenate(latent_vectors, axis=0)
validation_signals = np.concatenate(validation_signals, axis=0)

print("Validation signals:", validation_signals.shape)
print("Latent vectors:", latent_vectors.shape)

# %%
print("Latent minimum:", latent_vectors.min())
print("Latent maximum:", latent_vectors.max())
print("Latent mean:", latent_vectors.mean())
print("Latent std:", latent_vectors.std())

# %%
pca = PCA(n_components=2)
latent_pca = pca.fit_transform(latent_vectors)

print("Variance explained:",
      pca.explained_variance_ratio_)

# %%
plt.figure(figsize=(7, 6))
plt.scatter(latent_pca[:, 0], latent_pca[:, 1], s=10, alpha=0.5)
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()
